# %%
import pandas as pd
fok=pd.read_excel('cricRepo.xlsx')
fok
# Out:
#         team  run  run rate  wkt avg
# 0      india  220     12.00        6
# 1    england  180      9.20        2
# 2  australia  200     10.00       13
# 3    england  181      9.01       11
# 4   pakistan  101      4.00        5
# 5  australia  199      9.90        8
# 6   pakistan  209     11.00        9
# 7      india  170      8.50       10

# %%
 new=fok.groupby('team')
new

# %%
 for tm,rn in new:
        print(tm)
        print(rn)
# Out:
# australia
#         team  run  run rate  wkt avg
# 2  australia  200      10.0       13
# 5  australia  199       9.9        8
# england
#       team  run  run rate  wkt avg
# 1  england  180      9.20        2
# 3  england  181      9.01       11
# india
#     team  run  run rate  wkt avg
# 0  india  220      12.0        6
# 7  india  170       8.5       10
# pakistan
#        team  run  run rate  wkt avg
# 4  pakistan  101       4.0        5
# 6  pakistan  209      11.0        9

# %%
new.get_group('india')
# Out:
#     team  run  run rate  wkt avg
# 0  india  220      12.0        6
# 7  india  170       8.5       10

# %%
new.describe()
# Out:
#             run                                                         \
#           count   mean        std    min     25%    50%     75%    max
# team
# australia   2.0  199.5   0.707107  199.0  199.25  199.5  199.75  200.0
# england     2.0  180.5   0.707107  180.0  180.25  180.5  180.75  181.0
# india       2.0  195.0  35.355339  170.0  182.50  195.0  207.50  220.0
# pakistan    2.0  155.0  76.367532  101.0  128.00  155.0  182.00  209.0
#
#           run rate          ...                wkt avg                       \
#              count    mean  ...      75%   max   count  mean       std  min
# team                        ...
# australia      2.0   9.950  ...   9.9750  10.0     2.0  10.5  3.535534  8.0
# england        2.0   9.105  ...   9.1525   9.2     2.0   6.5  6.363961  2.0
# india          2.0  10.250  ...  11.1250  12.0     2.0   8.0  2.828427  6.0
# pakistan       2.0   7.500  ...   9.2500  11.0     2.0   7.0  2.828427  5.0
#
#
#             25%   50%    75%   max
# ...

# %%
new.plot()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [16], line 1
# ----> 1 new.plot()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:606, in GroupByPlot.__call__(self, *args, **kwargs)
#     603     return self.plot(*args, **kwargs)
#     605 f.__name__ = "plot"
# --> 606 return self._groupby.apply(f)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\groupby\groupby.py:1558, in GroupBy.apply(self, func, *args, **kwargs)
#    1556 with option_context("mode.chained_assignment", None):
#    1557     try:
# -> 1558         result = self._python_apply_general(f, self._selected_obj)
#    1559     except TypeError:
#    1560         # gh-20949
#    1561         # try again, with .apply acting as a filtering
#    (...)
#    1565         # fails on *some* columns, e.g. a numeric operation
# ...
